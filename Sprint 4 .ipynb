# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt


warnings.filterwarnings('ignore')

# %%
#EXERCICIES1---------------------
#Crea al menos una visualización para:
#Una variable categórica (Distrito o Barrio)
#Cargar la Data
#--------------------------
import pandas as pd
datos = pd.read_csv('C:/Users/HP/Downloads/preu.csv', header = 0)
print(datos.head())


 
# scatter plot illustration
plt.scatter(datos['Codi_Districte'], datos['Nom_Districte'])

# scatter plot illustration
my_plot = datos.plot("Codi_Districte", "Nom_Districte", kind="scatter")
plt.show()
# Out:
#     Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2021          1               1  Ciutat Vella           1
# 1  2021          1               1  Ciutat Vella           2
# 2  2021          1               1  Ciutat Vella           3
# 3  2021          1               1  Ciutat Vella           4
# 4  2021          1               2      Eixample           5
#
#                                Nom_Barri                      Lloguer_mitja  \
# 0                               el Raval  Lloguer mitjà mensual (Euros/mes)
# 1                         el Barri Gòtic  Lloguer mitjà mensual (Euros/mes)
# 2                         la Barceloneta  Lloguer mitjà mensual (Euros/mes)
# 3  Sant Pere, Santa Caterina i la Ribera  Lloguer mitjà mensual (Euros/mes)
# 4                          el Fort Pienc  Lloguer mitjà mensual (Euros/mes)
#
#     Preu
# 0  759.2
# 1  929.6
# 2  808.9
# 3  879.4
# 4  918.0

# %%
#Crea al menos una visualización para:
#Una variable numérica (Precio)
# Import seaborn
import matplotlib.pyplot as plt
plt.style.use('classic')
datos['Preu'].hist();

# %%
#Crea al menos una visualización para:
#Una variable numérica y una categórica (Distrito y Precio)



datos.plot.scatter(x='Preu',y='Codi_Districte')
# Out:
# <AxesSubplot:xlabel='Preu', ylabel='Codi_Districte'>

# %%
#Crea al menos una visualización para: Dos variables numéricas (Año o Trimestre y Precio)

sns.catplot(data=datos, x="Preu", y="Trimestre", kind="swarm")

# %%
#Tres variables (Barrio o Distrito, Trimestre y Precio)
pd.plotting.scatter_matrix(datos, figsize=(8, 8));

# %%
#Ejercicio 2
#Exporta los gráficos como imágenes o HTML.
i=0
plt.savefig(str(datos.columns[i])+'.png', dpi=100) 
i=i+1

# %%
#Ejercicio 3
#Proponer alguna visualización que creas que puede resultar interesante.
sns.displot(datos, x="Codi_Barri", hue="Nom_Districte", stat="density")

# %%
#Tasca M4 T02
#Ejercicio 1

# Open the choosen file
county = pd.read_csv('https://raw.githubusercontent.com/BIDDL3/Examining-Data/main/county.txt', sep='\t', encoding='utf-8')
print(county.head())

county.shape
county.columns
county.state.unique()
county.state.nunique()
county.describe().round(3)
county.pop2000.mean()
# Create data
x = county.fed_spend
y = county.poverty
colors = 'Blue'
area = np.pi*5

plt.axis([-10, 100, 0, 60])

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.4, edgecolors='black')

plt.title('Federal Spending vs Poverty by County')
plt.ylabel('Federal Spending per Capita')
plt.xlabel('Poverty Rate (Percent)')
plt.show()
# Out:
#              name    state   pop2000  pop2010  fed_spend  poverty  \
# 0  Autauga County  Alabama   43671.0    54571   6.068095     10.6
# 1  Baldwin County  Alabama  140415.0   182265   6.139862     12.2
# 2  Barbour County  Alabama   29038.0    27457   8.752158     25.0
# 3     Bibb County  Alabama   20826.0    22915   7.122016     12.6
# 4   Blount County  Alabama   51024.0    57322   5.130910     13.4
#
#    homeownership  multiunit  income  med_income
# 0           77.5        7.2   24568       53255
# 1           76.7       22.6   26469       50147
# 2           68.0       11.1   15875       33219
# 3           82.9        6.6   19918       41770
# 4           82.0        3.7   21070       45549

# %%
# Matrix Plot
sns.pairplot(county, diag_kind='hist', plot_kws={'alpha': 0.2})

# %%
county.describe()
county.hist(['fed_spend'], bins=14)
plt.title('Federal Spending vs Poverty by County')
plt.ylabel('Federal Spending per Capita')
plt.xlabel('Poverty Rate (Percent)')
plt.show()

# %%
county.fed_spend.mean()
# Out:
# 9.990674566074347

# %%
#Tasca M4 T02
#Ejercicio 2
#Realiza las tareas de preprocesado y adecuación del Dataset que disponemos en el repositorio de GitHub  PRE-PROCESSING-FECHA
# Open the choosen file
#Cargar la Data
#--------------------------


import pandas as pd

movie = pd.read_csv('‪‪C:/Users/HP/Documents/movie.csv', header = None)


print(movie.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [63], in <cell line: 11>()
#       1 #Tasca M4 T02
#       2 #Ejercicio 2
#       3 #Realiza las tareas de preprocesado y adecuación del Dataset que disponemos en el repositorio de GitHub  PRE-PROCESSING-FECHA
#       4 # Open the choosen file
#       5 #Cargar la Data
#       6 #--------------------------
#       9 import pandas as pd
# ---> 11 movie = pd.read_csv('‪‪C:/Users/HP/Documents/movie.csv', header = None)
#      14 print(movie.head())
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
movies = pd.read_csv('https://github.com/BIDDL3/PRE-PROCESSING-DATA/blob/main/movies.dat', sep='\t', encoding='utf-8')
print(movies.head())
# Out:
#                                      <!DOCTYPE html>
# 0  <html lang="en" data-color-mode="auto" data-li...
# 1                                             <head>
# 2                             <meta charset="utf-8">
# 3    <link rel="dns-prefetch" href="https://githu...
# 4    <link rel="dns-prefetch" href="https://avata...
